# %% [markdown]
# Basic Syntax and rules in python

# %%
name = "Eswar"
age = 25
height = 5.10

print(name)
print(age)
print(height)
# Out:
# Eswar
# 25
# 5.1

# %%
# Type inference
variable = "Eswar"
print(type(variable))
varaiable = 25
print(type(varaiable))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Indentation type
if age > 18:
    print("Eligable for vote")
# Out:
# Eligable for vote

# %%
## Case senstive 
name = "raju"
Name = "ramesh"
print(name)
print(Name)
# Out:
# raju
# ramesh

# %%
## Line continuation
total = 1+2+4+5+6+\
    8+9
print(total)
# Out:
# 35

# %%
## Code example of indentation
if True:
    print("correct indentation")
    if False:
        print("This one print")
    print("This will print")
print("Three time print will be print")
# Out:
# correct indentation
# This will print
# Three time print will be print
