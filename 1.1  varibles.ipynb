# %%
## Varibles
#variables are the containers which holds the value while executing the python program executed
# 1. Introduction to variable 
a=10
b=20
print(a+b)
# Out:
# 30

# %%
## Declaring and assigning the variables
age=25
height=5.10
name="Eswar"
is_student=True
print(age)
print(height)
print(name)
print(is_student)
# Out:
# 25
# 5.1
# Eswar
# True

# %%
## Namming convention
first_name="Ardhani"
last_name="Eswar"
print(first_name)
print(last_name)
# Out:
# Ardhani
# Eswar

# %%
## Invalid varible
#2age=20
#@name="Eswar"
# Out:
#   Cell In[4], line 2
#     2age=20
#     ^
# SyntaxError: invalid decimal literal

# %%
## case sensitive
name="Eswar"
Name="Ardhani"

# %%
## Understanding varible types
age=10
height=5.0
weight=30
name="Krish"
is_student=True
print(type(age))
print(type(height))
print(type(weight))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
## Type checking and conversion

age=2.5
print(type(int(age)))

## Type Conversion
age_str=str(age)
print(age_str)
print(type(age_str))

## inavalid error
#name="Eswar"
#int(name)
# Out:
# <class 'int'>
# 2.5
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 12
#       9 print(type(age_str))
#      11 name="Eswar"
# ---> 12 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Eswar'

# %%
## Dynamic typing
var=10
print(var,(type(var)))

var="Hello"
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
