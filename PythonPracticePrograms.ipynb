# %%
print('Hello World!')
# Out:
# Hello World!

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# identiders
area_23 = 10
_Full_name = 'Rana'

# %% [markdown]
# ### string as an array

# %%
s = 'python'

# %%
s[0]
# Out:
# 'p'

# %%
s[1]
# Out:
# 'y'

# %%
s[2]
# Out:
# 't'

# %%
s[3]
# Out:
# 'h'

# %%
s[4]
# Out:
# 'o'

# %%
s[5]
# Out:
# 'n'

# %%
s[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s[6]
#
# IndexError: string index out of range

# %%
s[-4]
# Out:
# 't'

# %%
s[-5]
# Out:
# 'y'

# %%
s[-1]
# Out:
# 'n'

# %% [markdown]
# ### string slicing

# %%
s
# Out:
# 'python'

# %%
str = 'Programming'

# %%
str[0:]
# Out:
# 'Programming'

# %%
str[0:5]
# Out:
# 'Progr'

# %%
str[1:]
# Out:
# 'rogramming'

# %%
str[-4:-2]
# Out:
# 'mi'

# %%
str[::-1]
# Out:
# 'gnimmargorP'

# %%
str[:5]
# Out:
# 'Progr'

# %%
str[5:]
# Out:
# 'amming'

# %%
str[:]
# Out:
# 'Programming'

# %%
str[::]
# Out:
# 'Programming'

# %%
str[1:-1]
# Out:
# 'rogrammin'

# %% [markdown]
# ### string methods

# %% [markdown]
# #### upper()

# %%
s1 = 'python'
s1
# Out:
# 'python'

# %%
for i in s1.upper():
    print(i,end= ' ')
# Out:
# P Y T H O N

# %%
s2 = 'programming language'
for i in s2.upper():
    print(i,end = ' ')
# Out:
# P R O G R A M M I N G   L A N G U A G E

# %%
str = 'python is a popular programming language'
for i in str.upper():
    print(i,end= ' ')
# Out:
# P Y T H O N   I S   A   P O P U L A R   P R O G R A M M I N G   L A N G U A G E

# %% [markdown]
# #### lower()

# %%
print(help(str.lower))
# Out:
# Help on built-in function lower:
#
# lower() method of builtins.str instance
#     Return a copy of the string converted to lowercase.
#
# None

# %%
s1 ='IT WAS CREATED BY GUIDO VAN RUSSAM AND RELEASED IN 1991'
for i in s1.lower():
    print(i,end= ' ')
# Out:
# i t   w a s   c r e a t e d   b y   g u i d o   v a n   r u s s a m   a n d   r e l e a s e d   i n   1 9 9 1

# %%
s2 = 'WHAT ARE THE FEATURES OF PYTHON PROGRAMMING LANGUAGE'
for i in s2.lower():
    print(i,end = ' ')
# Out:
# w h a t   a r e   t h e   f e a t u r e s   o f   p y t h o n   p r o g r a m m i n g   l a n g u a g e

# %%
str = 'PYTHON IS OPEN SOURCE PROGRAMMING LANGUAGE , PYTHON IS INTERPRETED BASED LANGUAGE , PYTHON IS DYNAMICALLY PROGRAMMING LANGUAGE'
for i in str.lower():
    print(i,end = ' ')
# Out:
# p y t h o n   i s   o p e n   s o u r c e   p r o g r a m m i n g   l a n g u a g e   ,   p y t h o n   i s   i n t e r p r e t e d   b a s e d   l a n g u a g e   ,   p y t h o n   i s   d y n a m i c a l l y   p r o g r a m m i n g   l a n g u a g e

# %% [markdown]
# #### capitalize()

# %%
print(help(str.capitalize))
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.
#
# None

# %%
s1 = 'python is platfrom independent language'
for i in s1.capitalize():
    print(i,end = ' ')
# Out:
# P y t h o n   i s   p l a t f r o m   i n d e p e n d e n t   l a n g u a g e

# %%
s2 = 'python supports OOPs'
for i in s2.capitalize():
    print(i, end = ' ')
# Out:
# P y t h o n   s u p p o r t s   o o p s

# %%
s3 = 'python HAVE rich SET of LIBRARY'
for i in s3.capitalize():
    print(i,end = ' ')
# Out:
# P y t h o n   h a v e   r i c h   s e t   o f   l i b r a r y

# %% [markdown]
# #### title()

# %%
print(help(str.title))
# Out:
# Help on built-in function title:
#
# title() method of builtins.str instance
#     Return a version of the string where each word is titlecased.
#
#     More specifically, words start with uppercased characters and all remaining
#     cased characters have lower case.
#
# None

# %%
s1 = 'python is easy to learn and esay to code'
for i in s1.title():
    print(i,end = ' ')
# Out:
# P y t h o n   I s   E a s y   T o   L e a r n   A n d   E s a y   T o   C o d e

# %%
s2 = 'PYTHON HAVE EXCEPTION HANDLING TECHNIQUES'
for i in s2.title():
    print(i,end = ' ')
# Out:
# P y t h o n   H a v e   E x c e p t i o n   H a n d l i n g   T e c h n i q u e s

# %% [markdown]
# #### count()

# %%
print(help(str.count))
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.
#
# None

# %%
s1 = 'keywords are resevered words which have specal meaning'
for i in s1.count('o'):
    print(i,end = ' ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 s1 = 'keywords are resevered words which have specal meaning'
# ----> 2 for i in s1.count('o'):
#       3     print(i,end = ' ')
#
# TypeError: 'int' object is not iterable

# %%
s1.count('o')
# Out:
# 2

# %%
s1.count('e')
# Out:
# 9

# %%
s1.count('a')
# Out:
# 4

# %% [markdown]
# #### split()

# %%
print(help(str.split))
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \n \r \t \f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits (starting from the left).
#         -1 (the default value) means no limit.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.
#
# None

# %%
s1 = 'Keywords are used for write the meaningful instruction'
s1.split()
# Out:
# ['Keywords', 'are', 'used', 'for', 'write', 'the', 'meaningful', 'instruction']

# %%
s2 = 'Keywords/are/case/sensitive'
s2.split('/')
# Out:
# ['Keywords', 'are', 'case', 'sensitive']

# %%
s3 = 'Identifiers are name@of@class@variables@functions@is called@identifers'
s3.split('@')
# Out:
# ['Identifiers are name',
#  'of',
#  'class',
#  'variables',
#  'functions',
#  'is called',
#  'identifers']

# %% [markdown]
# ### replace()

# %%
print(help(str.replace))
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.
#
# None

# %%
s1 = 'A operator is a symbol that perform the operation by using variables and operands'
s1.replace('o','a')
# Out:
# 'A aperatar is a symbal that perfarm the aperatian by using variables and aperands'

# %%
s1.replace('t','m')
# Out:
# 'A operamor is a symbol mham perform mhe operamion by using variables and operands'

# %%
s1.replace('u','h')
# Out:
# 'A operator is a symbol that perform the operation by hsing variables and operands'

# %% [markdown]
# #### startswith()

# %%
print(help(str.startswith))
# Out:
# Help on built-in function startswith:
#
# startswith(...) method of builtins.str instance
#     S.startswith(prefix[, start[, end]]) -> bool
#
#     Return True if S starts with the specified prefix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     prefix can also be a tuple of strings to try.
#
# None

# %%
s1 = 'programming'
s1.startswith('p')
# Out:
# True

# %%
s1.startswith('pr')
# Out:
# True

# %%
s1.startswith('g')
# Out:
# False

# %% [markdown]
# #### endswith()

# %%
print(help(str.endswith))
# Out:
# Help on built-in function endswith:
#
# endswith(...) method of builtins.str instance
#     S.endswith(suffix[, start[, end]]) -> bool
#
#     Return True if S ends with the specified suffix, False otherwise.
#     With optional start, test S beginning at that position.
#     With optional end, stop comparing S at that position.
#     suffix can also be a tuple of strings to try.
#
# None

# %%
s2 = 'python'
s2.endswith('n')
# Out:
# True

# %%
s2.endswith('on')
# Out:
# True

# %%
s2.endswith('thon')
# Out:
# True

# %%
s2.endswith('py')
# Out:
# False

# %% [markdown]
# #### index()

# %%
print(help(str.index))
# Out:
# Help on built-in function index:
#
# index(...) method of builtins.str instance
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.
#
# None

# %%
s1 = 'progarmming'
s1.index('m')
# Out:
# 6

# %%
s1.index('g')
# Out:
# 3

# %%
s1.index('r')
# Out:
# 1

# %% [markdown]
# #### rindex()

# %%
print(help(str.rindex))
# Out:
# Help on built-in function rindex:
#
# rindex(...) method of builtins.str instance
#     S.rindex(sub[, start[, end]]) -> int
#
#     Return the highest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.
#
# None

# %%
s2 = 'python is esay good programming language'
s2.rindex('o')
# Out:
# 22

# %%
s2.rindex('g')
# Out:
# 38

# %%
s2.rindex('d')
# Out:
# 18

# %%
s2.rindex('j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 s2.rindex('j')
#
# ValueError: substring not found

# %% [markdown]
# #### find()

# %%
print(help(str.find))
# Out:
# Help on built-in function find:
#
# find(...) method of builtins.str instance
#     S.find(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.
#
# None

# %%
str = 'we are planning vaccation'
str.find('n')
# Out:
# 10

# %%
str.find('a')
# Out:
# 3

# %%
str.find('h')
# Out:
# -1

# %% [markdown]
# #### rfind()

# %%
print(help(str.rfind))
# Out:
# Help on built-in function rfind:
#
# rfind(...) method of builtins.str instance
#     S.rfind(sub[, start[, end]]) -> int
#
#     Return the highest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.
#
# None

# %%
str1 = 'we will walk after few hours laters'
str1.rfind('l')
# Out:
# 29

# %%
str.rfind('r')
# Out:
# 4

# %%
str.rfind('x')
# Out:
# -1

# %% [markdown]
# #### strip()

# %%
print(help(str.strip))
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.
#
# None

# %%
a = '   India is a developing country  '
a.strip()
# Out:
# 'India is a developing country'

# %%
b = '               Enjoy the weekend      '
b.strip()
# Out:
# 'Enjoy the weekend'

# %% [markdown]
# #### rstrip()

# %%
print(help(str.rstrip))
# Out:
# Help on built-in function rstrip:
#
# rstrip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.
#
# None

# %%
a
# Out:
# '   India is a developing country  '

# %%
a.rstrip()
# Out:
# '   India is a developing country'

# %%
b.rstrip()
# Out:
# '               Enjoy the weekend'

# %% [markdown]
# #### lstrip()

# %%
print(help(str.lstrip))
# Out:
# Help on built-in function lstrip:
#
# lstrip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.
#
# None

# %%
a.lstrip()
# Out:
# 'India is a developing country  '

# %%
b.lstrip()
# Out:
# 'Enjoy the weekend      '

# %% [markdown]
# #### isdigit()

# %%
print(help(str.isdigit))
# Out:
# Help on method_descriptor:
#
# isdigit(self, /)
#     Return True if the string is a digit string, False otherwise.
#
#     A string is a digit string if all characters in the string are digits and there
#     is at least one character in the string.
#
# None

# %%
s = 'progra123mming134'
s.isdigit()
# Out:
# False

# %%
s1 = '12345'
s1.isdigit()
# Out:
# True

# %% [markdown]
# #### isalnum

# %%
print(help(str.isalnum))
# Out:
# Help on method_descriptor:
#
# isalnum(self, /)
#     Return True if the string is an alpha-numeric string, False otherwise.
#
#     A string is alpha-numeric if all characters in the string are alpha-numeric and
#     there is at least one character in the string.
#
# None

# %%
a = '1234'
a.isalnum()
# Out:
# True

# %%
a = 'p123y@234h'
a.isalnum()
# Out:
# True

# %%
a.isalnum()
# Out:
# True

# %%
b = 'python@123'
b.isalnum()
# Out:
# False

# %% [markdown]
# #### isalpha()

# %%
print(help(str.isalpha))
# Out:
# Help on method_descriptor:
#
# isalpha(self, /)
#     Return True if the string is an alphabetic string, False otherwise.
#
#     A string is alphabetic if all characters in the string are alphabetic and there
#     is at least one character in the string.
#
# None

# %%
str = 'I am learning python programming language'
str.isalpha()
# Out:
# False

# %%
str1 = 'Programming'
str.isalpha()
# Out:
# False

# %%
str3 = 'PrograMMIng'
str3.isalpha()
# Out:
# True

# %% [markdown]
# #### islower()

# %%
print(help(str.islower))
# Out:
# Help on built-in function islower:
#
# islower() method of builtins.str instance
#     Return True if the string is a lowercase string, False otherwise.
#
#     A string is lowercase if all cased characters in the string are lowercase and
#     there is at least one cased character in the string.
#
# None

# %%
s1 = 'PYTHON'
s1.islower()
# Out:
# False

# %%
s2 = 'python'
s2.islower()
# Out:
# True

# %% [markdown]
# #### isupper()

# %%
s1 = 'PROGRAMMING'
s1.isupper()
# Out:
# True

# %%
s2.isupper()
# Out:
# False

# %% [markdown]
# #### format()

# %%
print(help(str.format))
# Out:
# Help on built-in function format:
#
# format(...) method of builtins.str instance
#     S.format(*args, **kwargs) -> str
#
#     Return a formatted version of S, using substitutions from args and kwargs.
#     The substitutions are identified by braces ('{' and '}').
#
# None

# %%
a = 10
b = 30
c = b-a
d = a + b
print('The addition result {}, The subtraction result {}'.format(c,d))
# Out:
# The addition result 20, The subtraction result 40

# %%
name = 'Eswar'
age = 25
print(f'my name {name}, my Age {age}')
# Out:
# my name Eswar, my Age 25

# %% [markdown]
# #### join()

# %%
print(help(str.join))
# Out:
# Help on built-in function join:
#
# join(iterable, /) method of builtins.str instance
#     Concatenate any number of strings.
#
#     The string whose method is called is inserted in between each given string.
#     The result is returned as a new string.
#
#     Example: '.'.join(['ab', 'pq', 'rs']) -> 'ab.pq.rs'
#
# None

# %%
L = ['python' ,'is', 'a' ,'programming' ,'language']
' '.join(L)
# Out:
# 'python is a programming language'

# %%
'@'.join(L)
# Out:
# 'python@is@a@programming@language'

# %%
'/'.join(L)
# Out:
# 'python/is/a/programming/language'

# %% [markdown]
# #### center()

# %%
a = 'python'
a.center(10)
# Out:
# '  python  '

# %% [markdown]
# ### Strings

# %% [markdown]
# #### 1. Write a program to print a reverse string without using built-in functions and indexings

# %%
str = 'Programming'
rev = ''
for i in str:
    rev = i + rev
print(rev)
# Out:
# gnimmargorP

# %%
S = 'python'
print(S[::-1])
# Out:
# nohtyp

# %%
str1 = ' I am learning python programming language'
rev = ''
for i in str1:
    rev = i + rev
print(rev)
# Out:
# egaugnal gnimmargorp nohtyp gninrael ma I

# %% [markdown]
# #### write a program to check the given string is palindome or Not

# %%
rev = ''
str = 'malayalam'
for i in str:
    rev = i + rev 
if rev == str:
    print('Given string is palindrome')
else:
    print('Given string is not a palindrome')
# Out:
# Given string is palindrome

# %%
str1 = input('Enter a string :')
rev = ''
for i in str1:
    rev = i + rev
if rev == str:
    print('palindrome')
else:
    print('Not palindrome')
# Out:
# Enter a string : Eswar
# Not palindrome

# %%
rev = ''
str = 'madam'
rev = str[::-1]
if rev == str:
    print('palindrome')
else:
    print('Not palindrome')
# Out:
# palindrome

# %%
rev = ''
str = input('Enter a string :')
rev = str[::-1]
if rev == str:
    print('palindrome')
else:
    print('Not Palindrome')
# Out:
# Enter a string : madam
# palindrome

# %% [markdown]
# ### write a program to remove duplicates from a string

# %%
str = 'programming'
result = ''
for i in str:
    if i not in result:
        result += i
print(result)
# Out:
# progamin

# %%
str = 'we try to practice programming language'
result = ''
for i in str:
    if i not in result:
        result += i
print(result)
# Out:
# we tryopacigmnlu

# %% [markdown]
# #### write a program to print frequency of a given string without using list comphrension

# %%
str = 'programming'
freq= {}
for i in str:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1
print(freq)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
str
# Out:
# 'programming'

# %%
{i:str.count(i) for i in str}
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
# reverse a string
S = 'programming'
print(S[::-1]) # with using index
# Out:
# gnimmargorp

# %%
# without using built in functions
rev = ''
str = 'python programming'
for i in str:
    rev = i + rev
print(rev)
# Out:
# gnimmargorp nohtyp

# %%
# palindrome or not
rev = ''
str1 = 'madam'
for i in str1:
    rev = i + rev
if rev == str1:
    print('palindrome')
else:
    print('Not a palindrome')
# Out:
# palindrome

# %%
# with using built in functions
rev = ''
S = 'python'
rev = S[::-1]
if rev == S:
    print('palindome')
else:
    print('Not a palindrome')
# Out:
# Not a palindrome

# %%
# remove duplicates from string
str = 'programming'
result = ''
for i in str:
    if i not in result:
        result += i
print(result)
# Out:
# progamin

# %%
# frequency of given string
freq = {}
S = 'programming'
for i in S:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1
print(freq)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
S
# Out:
# 'programming'

# %%
{i:S.count(i) for i in S}
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1}

# %%
# Reverse a string without using built in function
str = 'Programming'
rev = ''
for i in str:
    rev = i + rev
print(rev)
# Out:
# gnimmargorP

# %%
str
# Out:
# 'Programming'

# %%
print(str[::-1])
# Out:
# gnimmargorP

# %%
# palindrome or not
rev = ''
S = 'malayalam'
for i in S:
    rev = i + rev
if rev == S:
    print('palindrome')
else:
    print('Not a palindrome')
# Out:
# palindrome
